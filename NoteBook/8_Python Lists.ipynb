# %% [markdown]
# # Python Lists
#
# Lists are collection of different type of elements

# %%
a = 10
b = 20

# %%
a1 = 10
a2 = 20
a3 = 30

# %%
l = [10, 200, 30, 40]
print(l)
# Out:
# [10, 200, 30, 40]

# %%
l = ["A", 100, 5, 10.5,True]
#    l[0]    1   2   3
print(l)
# Out:
# ['A', 100, 5, 10.5, True]

# %%
Haidy=['Haidy','Data Scientist','GoMyCode',100,20000]
print(Haidy[4])
# Out:
# 20000

# %%
print(Haidy[4])
Haidy[4] = 50000
print(Haidy[4])
print(Haidy)
# Out:
# 50000
# 50000
# ['Haidy', 'Data Scientist', 'GoMyCode', 100, 50000]

# %%
print(l[1])
# Out:
# 100

# %%
print(l[3])
# Out:
# 10.5

# %%
print(l[2])
# Out:
# 5

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
print(type(l[0]))
# Out:
# <class 'str'>

# %%
print(type(Haidy[4]))
# Out:
# <class 'int'>

# %%
a = 10
a = 20
print(a)
# Out:
# 20

# %%
my_string = "Mohamed"
print("my_string[1:5] = ", my_string[1:5:2])  #slicing 2nd to 5th character                 my_string[1:5] =  elco
print("my_string[5:-2] = ", my_string[:])   #slicing 6th to 2nd last character
# Out:
# my_string[1:5] =  oa
# my_string[5:-2] =  Mohamed

# %%
my_string= 'H'
my_string
# Out:
# 'H'

# %%
my_string[0]='T'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-50967ec55ade> in <cell line: 1>()
# ----> 1 my_string[0]='T'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'HEoLO'
s=s[:2]+'L'+s[3:]
s
# Out:
# 'HELLO'

# %%
s="abc"
s="d"+s[1:]
s
# Out:
# 'dbc'

# %%
l = [1,2,14,5]

print(l)

l[2] = 10

print(l)
# Out:
# [1, 2, 14, 5]
# [1, 2, 10, 5]

# %%
n = 55

l = [1,2,3,n]

print(l)
# Out:
# [1, 2, 3, 55]

# %%
l = [1,2,3,44]

l[4] = 88

print(l)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-3004ff7f3a34> in <cell line: 3>()
#       1 l = [1,2,3,44]
#       2
# ----> 3 l[4] = 88
#       4
#       5 print(l)
#
# IndexError: list assignment index out of range

# %%
l = [1,2,3,44]

l.append(88)

print(l)
# Out:
# [1, 2, 3, 44, 88]

# %%
l = []
l.append(5)
print(l)
# Out:
# [5]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
#   -6  -5-4 - -23 -1
l = [70,50,3,50,20,10]
#    0  1  2  3 4  5
print(l[-1::-1])
print(l[::-1])
print(list(reversed(l)))
# Out:
# [10, 20, 50, 3, 50, 70]
# [10, 20, 50, 3, 50, 70]
# ...

# %%
l = [70,50,3,50,20,10]
print(l)
l.reverse()
print(l)
# Out:
# [70, 50, 3, 50, 20, 10]
# [10, 20, 50, 3, 50, 70]

# %%
print(l[-6])
# Out:
# 10

# %%
print(l[0])
# Out:
# 70

# %% [markdown]
# # List Slicing

# %%
n = [11,4,8,16,32,64,128,100,256]
#     0 1 2  3  4  5  6   7   8

print(n[0:4])
# Out:
# [11, 4, 8, 16]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[3:7])
# Out:
# [16, 32, 64, 128]

# %%
print(n[5:])
# Out:
# [64, 128, 100, 256]

# %%
print(n[:3])
# Out:
# [11, 4, 8]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[0:2])
# Out:
# [11, 4]

# %%
print(n[0:1])
# Out:
# [11]

# %%
print(n[0:4])
# Out:
# [11, 4, 8, 16]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[4:0])
# Out:
# []

# %%
print(n[-4:-1])
# Out:
# [64, 128, 100]

# %%
print(n[-1:-4])
# Out:
# []

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[-7:])
# Out:
# [8, 16, 32, 64, 128, 100, 256]

# %%
print(n[-1:])
# Out:
# [256]

# %%
print(n[2:-4])
# Out:
# [8, 16, 32]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[:])
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[::2])  # steps
# Out:
# [11, 8, 32, 128, 256]

# %%
print(n[::4])
# Out:
# [11, 32, 256]

# %%
print(n[::1])
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[::-1])
# Out:
# [256, 100, 128, 64, 32, 16, 8, 4, 11]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[0:5:2])
# Out:
# [11, 8, 32]

# %%
print(n[8:1:])
# Out:
# []

# %%
print(n[8:1:-1])
# Out:
# [256, 100, 128, 64, 32, 16, 8]

# %%
print(n)
# Out:
# [11, 4, 8, 16, 32, 64, 128, 100, 256]

# %%
print(n[8:1:-2])
# Out:
# [256, 128, 32, 8]

# %%
print(n[4:1:-1])
# Out:
# [32, 16, 8]

# %%
print(n[1:4:-1])
# Out:
# []

# %%
print(n[1:7:0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-219e3b9d50fa> in <module>
# ----> 1 print(n[1:7:0])
#
# ValueError: slice step cannot be zero
